# %% [markdown]
# Tutorial goal:  Learn Jupyter Notebooks and python at the same time.
#
# Steps:
#     1) Read in csv files & review the data
#     2) Unify the data
#     3)
#
# Questions:
#     1) How to run a cell in debug???
#     2) How to get output?
#     3) How to run consequetive cells?
#     4) Does markdown contain spell check?

# %%
# Testing Import

import numpy as np
#"hs_directory.csv",
files = ["ap_2010.csv", "class_size.csv", "demographics.csv", "graduation.csv", "math_test_results.csv", "sat_results.csv"]

data = {}
for f in files:
    d = pandas.read_csv("C:\\Users\\bzelasky\\Documents\\Python Scripts\\schools\\{0}".format(f))
    data[f.replace(".csv", "")] = d
    
for k,v in data.items():
    print("\n" + k + "\n")
    print(v.head())
# Out:
# ap_2010
#
#       DBN                             SchoolName AP Test Takers   \
# 0  01M448           UNIVERSITY NEIGHBORHOOD H.S.              39
# 1  01M450                 EAST SIDE COMMUNITY HS              19
# 2  01M515                    LOWER EASTSIDE PREP              24
# 3  01M539         NEW EXPLORATIONS SCI,TECH,MATH             255
# 4  02M296  High School of Hospitality Management               s
#
#   Total Exams Taken Number of Exams with scores 3 4 or 5
# 0                49                                   10
# 1                21                                    s
# 2                26                                   24
# 3               377                                  191
# 4                 s                                    s
#
# class_size
#
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# ...
